# %% [markdown]
# <a href="https://colab.research.google.com/github/adapasriram/US_HONEY_PRODUCTION/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/US_honey_dataset.csv')

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
#        stocks  average_price  value_of_production  year
# 0       28000          62.00               575000  1995
# 1      986000          68.00              2793000  1995
# 2      900000          64.00              1920000  1995
# 3     4687000          60.00             23436000  1995
# 4     1404000          68.00              1836000  1995
# ...       ...            ...                  ...   ...
# 1110    79000           8.23              1975000  2021
# 1111  1206000           2.52              7741000  2021
# 1112   136000           4.80              1238000  2021
# 1113   750000           2.81              5547000  2021
# 1114   242000           2.07              4562000  2021
#
# [1115 rows x 9 columns]

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
df
# Out:
#              state  colonies_number  yield_per_colony  production   stocks  \
# 0          Alabama            16000                58      928000    28000
# 1          Arizona            52000                79     4108000   986000
# 2         Arkansas            50000                60     3000000   900000
# 3       California           420000                93    39060000  4687000
# 4         Colorado            45000                60     2700000  1404000
# ...            ...              ...               ...         ...      ...
# 1110      Virginia             6000                40       79000    79000
# 1111    Washington            96000                32     1206000  1206000
# 1112  WestVirginia             6000                43      136000   136000
# 1113     Wisconsin            42000                47      750000   750000
# 1114       Wyoming            38000                58      242000   242000
#
#       average_price  value_of_production  year
# 0             62.00               575000  1995
# 1             68.00              2793000  1995
# 2             64.00              1920000  1995
# 3             60.00             23436000  1995
# 4             68.00              1836000  1995
# ...             ...                  ...   ...
# 1110           8.23              1975000  2021
# 1111           2.52              7741000  2021
# 1112           4.80              1238000  2021
# 1113           2.81              5547000  2021
# 1114           2.07              4562000  2021
#
# [1115 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                1115 non-null   object
#  1   colonies_number      1115 non-null   int64
#  2   yield_per_colony     1115 non-null   int64
#  3   production           1115 non-null   int64
#  4   stocks               1115 non-null   int64
#  5   average_price        1115 non-null   float64
#  6   value_of_production  1115 non-null   int64
#  7   year                 1115 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 69.8+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0             0
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#check how many states are there
df['state'].nunique()
# Out:
# 44

# %%
df['year'].nunique()
# Out:
# 27

# %%
1.Which states are rarely contributing to honey production for the last 27 years

# %%
data = df['state'].value_counts(ascending = True).head(5)

# %%
data
# Out:
# state
# Oklahoma          9
# Maryland          9
# SouthCarolina    12
# Nevada           15
# NewMexico        18
# Name: count, dtype: int64

# %%
data
# Out:
# state
# Oklahoma          9
# Maryland          9
# SouthCarolina    12
# Nevada           15
# NewMexico        18
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,8))
colors = plt.cm.viridis_r.colors

plt.pie(data.values,labels = data.index,
        autopct = '%.1f%%',
        colors = colors)

plt.title('pie chart')
plt.tight_layout()
plt.show()

# %%
data = df['state'].value_counts()

colors = ['red' if value < 18 else 'green' for value in data]
data.plot(kind = 'bar',color = colors)
plt.xlabel('State')
plt.ylabel('Count')
plt.title('Count of Honey Production by State')
# Out:
# Text(0.5, 1.0, 'Count of Honey Production by State')

# %%
df_sorted = df.sort_values(by = 'production',ascending = False)

# %%
plt.figure(figsize = (10,5))
sns.barplot(
    x = df_sorted['state'],
    y = df_sorted['production'],
    palette = 'pastel',
    edgecolor = 'black'
)
plt.xticks(rotation = 90)

plt.xlabel('state')
plt.ylabel('production')
plt.title('state vs proiduction')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6371/281662758.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_sorted
# Out:
#      Unnamed: 0          state  colonies_number  yield_per_colony  production  \
# 3             3     California           420000                93    39060000
# 134         134     California           450000                83    37350000
# 581         581    NorthDakota           390000                90    35100000
# 622         622    NorthDakota           450000                77    34650000
# 458         458    NorthDakota           370000                91    33670000
# ..          ...            ...              ...               ...         ...
# 769         769       Kentucky             3000                41       17000
# 984         984  SouthCarolina            16000                48       15000
# 955         955        Alabama             6000                45       14000
# 835         835        Alabama             7000                47       13000
# 689         689       Kentucky             4000                39       12000
#
#        stocks  average_price  value_of_production  year
# 3     4687000          60.00             23436000  1995
# 134  12326000          62.00             23157000  1998
# 581   8424000         135.00             47385000  2008
# 622   7623000         137.00             47471000  2009
# 458   8418000          81.00             27273000  2005
# ..        ...            ...                  ...   ...
# 769     17000         325.00               400000  2013
# 984     15000           3.17              2435000  2018
# 955     14000           3.72              1004000  2018
# 835     13000         383.00              1260000  2015
# 689     12000         317.00               495000  2011
#
# [1115 rows x 9 columns]

# %% [markdown]
# 3.WHAT IS THE CHANGE IN MEAN AVERAGE PRICE OF HONEY FROM 1995 TO 2021

# %%
df2 = df.groupby('year').mean(['average_price'])

# %%
df2
# Out:
#       Unnamed: 0  colonies_number  yield_per_colony    production  \
# year
# 1995        21.5     59977.272727         66.909091  4.778909e+06
# 1996        65.5     58181.818182         70.068182  4.499886e+06
# 1997       109.0     59651.162791         68.953488  4.445953e+06
# 1998       152.0     60883.720930         69.953488  5.100488e+06
# 1999       195.0     62186.046512         65.465116  4.757791e+06
# 2000       238.0     60860.465116         67.534884  5.123721e+06
# 2001       281.0     58139.534884         65.209302  4.311698e+06
# 2002       324.5     57181.818182         67.272727  3.880273e+06
# 2003       368.5     58681.818182         62.522727  4.107750e+06
# 2004       410.5     63325.000000         65.025000  4.559475e+06
# 2005       451.0     58341.463415         64.268293  4.240415e+06
# 2006       492.0     57926.829268         61.853659  3.759024e+06
# 2007       533.0     59121.951220         59.390244  3.600220e+06
# 2008       574.0     55756.097561         61.000000  3.904780e+06
# 2009       615.0     59682.926829         53.780488  3.496098e+06
# 2010       655.5     66650.000000         56.275000  1.119925e+06
# 2011       695.5     61650.000000         54.775000  9.137500e+05
# 2012       735.5     62725.000000         55.175000  7.915500e+05
# 2013       775.0     66846.153846         52.974359  9.736923e+05
# 2014       814.5     67725.000000         57.350000  1.024750e+06
# 2015       854.5     65750.000000         55.325000  1.045800e+06
# 2016       894.5     68500.000000         54.075000  1.020925e+06
# 2017       934.5     66225.000000         53.425000  7.619500e+05
# 2018       974.5     69800.000000         50.875000  7.247250e+05
# 2019      1014.5     69550.000000         51.050000  1.012750e+06
# 2020      1054.5     66825.000000         50.000000  9.853000e+05
# 2021      1094.5     66700.000000         46.700000  5.796750e+05
#
#             stocks  average_price  value_of_production
# year
# 1995  9.575000e+05      74.840909         3.121000e+06
# 1996  1.066455e+06      99.568182         4.085773e+06
# 1997  1.601256e+06      91.325581         3.386000e+06
# 1998  1.871488e+06      83.720930         3.395302e+06
# 1999  1.839698e+06      80.325581         2.888070e+06
# 2000  1.997395e+06      79.023256         3.047023e+06
# 2001  1.501791e+06      88.465116         2.936302e+06
# 2002  8.831591e+05     133.204545         5.016977e+06
# 2003  9.220227e+05     151.068182         5.791659e+06
# 2004  1.523100e+06     132.350000         4.976100e+06
# 2005  1.515732e+06     116.341463         3.795390e+06
# 2006  1.469610e+06     134.341463         3.886902e+06
# 2007  1.273488e+06     140.170732         3.801634e+06
# 2008  1.227195e+06     160.878049         5.466171e+06
# 2009  9.030732e+05     176.195122         5.063463e+06
# 2010  1.119925e+06     192.900000         6.959250e+06
# 2011  9.137500e+05     216.725000         6.467200e+06
# 2012  7.915500e+05     236.700000         7.018125e+06
# 2013  9.736923e+05     260.717949         8.079949e+06
# 2014  1.024750e+06     282.025000         9.612075e+06
# 2015  1.045800e+06     292.625000         8.062625e+06
# 2016  1.020925e+06     291.925000         8.382125e+06
# 2017  7.619500e+05     302.775000         8.154950e+06
# 2018  7.247250e+05       3.083500         8.269150e+06
# 2019  1.012750e+06       2.925500         7.585950e+06
# 2020  9.853000e+05       3.050000         7.545775e+06
# 2021  5.796750e+05       3.334250         7.860325e+06

# %%
plt.figure(figsize = (10,5))
sns.lineplot(
    x = df2.index,
    y = df2['average_price'],
    color = 'green'
)
plt.xlabel('year')
plt.ylabel('average price')
plt.title('change in mean price of honey(1995-2021)')
plt.show()

# %% [markdown]
# 3  Which was the year when production of honey in wholeUS was the highest

# %%
data3 = df.groupby('year').sum()['production'].reset_index()

# %%
data3
# Out:
#     year  production
# 0   1995   210272000
# 1   1996   197995000
# 2   1997   191176000
# 3   1998   219321000
# 4   1999   204585000
# 5   2000   220320000
# 6   2001   185403000
# 7   2002   170732000
# 8   2003   180741000
# 9   2004   182379000
# 10  2005   173857000
# 11  2006   154120000
# 12  2007   147609000
# 13  2008   160096000
# 14  2009   143340000
# 15  2010    44797000
# 16  2011    36550000
# 17  2012    31662000
# 18  2013    37974000
# 19  2014    40990000
# 20  2015    41832000
# 21  2016    40837000
# 22  2017    30478000
# 23  2018    28989000
# 24  2019    40510000
# 25  2020    39412000
# 26  2021    23187000

# %%
data3_sorted = data3.sort_values(by='production',ascending = False)

# %%
plt.figure(figsize = (15,8))
sns.barplot(x = data3['year'],y = data3['production'],
        palette = 'magma',
        edgecolor = 'black'
        )

plt.title('year wise production')
plt.xlabel('year')
plt.ylabel('production')
plt.xticks(rotation = 45)
plt.yticks(rotation = 45)
plt.grid(axis = 'y',linestyle = '--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_6371/2267543019.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = data3['year'],y = data3['production'],

# %%
data = df[df['year'] == 2000]

# %%
data
# Out:
#      Unnamed: 0          state  colonies_number  yield_per_colony  production  \
# 217         217        Alabama            16000                78     1248000
# 218         218        Arizona            40000                59     2360000
# 219         219       Arkansas            55000                93     5115000
# 220         220     California           440000                70    30800000
# 221         221       Colorado            29000                60     1740000
# 222         222        Florida           232000               105    24360000
# 223         223        Georgia            55000                57     3135000
# 224         224         Hawaii             7000               112      784000
# 225         225          Idaho           100000                47     4700000
# 226         226       Illinois             8000                61      488000
# 227         227        Indiana             8000                65      520000
# 228         228           Iowa            30000                67     2010000
# 229         229         Kansas            15000                68     1020000
# 230         230       Kentucky             3000                48      144000
# 231         231      Louisiana            43000                94     4042000
# 232         232          Maine            11000                21      231000
# 233         233       Maryland             6000                46      276000
# 234         234       Michigan            72000                75     5400000
# 235         235      Minnesota           150000                90    13500000
# 236         236    Mississippi            17000                72     1224000
# 237         237       Missouri            23000                75     1725000
# 238         238        Montana           148000                86    12728000
# 239         239       Nebraska            50000                87     4350000
# 240         240         Nevada            10000                35      350000
# 241         241      NewJersey            11000                35      385000
# 242         242      NewMexico            15000                64      960000
# 243         243        NewYork            58000                80     4640000
# 244         244  NorthCarolina            11000                49      539000
# 245         245    NorthDakota           290000               115    33350000
# 246         246           Ohio            18000                65     1170000
# 247         247       Oklahoma             7000                35      245000
# 248         248         Oregon            48000                51     2448000
# 249         249   Pennsylvania            22000                45      990000
# 250         250    SouthDakota           235000               121    28435000
# 251         251      Tennessee             9000                61      549000
# 252         252          Texas           105000                79     8295000
# 253         253           Utah            24000                41      984000
# 254         254        Vermont             7000                59      413000
# 255         255       Virginia             7000                42      294000
# 256         256     Washington            52000                54     2808000
# 257         257   WestVirginia             7000                54      378000
# 258         258      Wisconsin            84000                90     7560000
# 259         259        Wyoming            39000                93     3627000
#
#        stocks  average_price  value_of_production  year
# 217    187000           59.0               736000  2000
# 218   1322000           73.0              1723000  2000
# 219   3529000           57.0              2916000  2000
# 220  11396000           58.0             17864000  2000
# 221    957000           62.0              1079000  2000
# 222   2923000           54.0             13154000  2000
# 223    376000           63.0              1975000  2000
# 224    125000           81.0               635000  2000
# 225   2679000           52.0              2444000  2000
# 226    146000          117.0               571000  2000
# 227    286000          103.0               536000  2000
# 228   1206000           67.0              1347000  2000
# 229    520000           91.0               928000  2000
# 230     40000          135.0               194000  2000
# 231   1334000           52.0              2102000  2000
# 232    143000           75.0               173000  2000
# 233     52000          114.0               315000  2000
# 234   2970000           60.0              3240000  2000
# 235   3105000           57.0              7695000  2000
# 236    649000           69.0               845000  2000
# 237    362000           60.0              1035000  2000
# 238   5982000           59.0              7510000  2000
# 239   2610000           59.0              2567000  2000
# 240     95000          145.0               508000  2000
# 241    200000           61.0               235000  2000
# 242    739000           72.0               691000  2000
# 243   2274000           55.0              2552000  2000
# 244    243000          143.0               771000  2000
# 245  13340000           56.0             18676000  2000
# 246    585000           79.0               924000  2000
# 247     64000          126.0               309000  2000
# 248   1665000           66.0              1616000  2000
# 249    554000           76.0               752000  2000
# 250  12796000           57.0             16208000  2000
# 251    104000          143.0               785000  2000
# 252   2986000           57.0              4728000  2000
# 253    462000           60.0               590000  2000
# 254    211000           68.0               281000  2000
# 255    103000          150.0               441000  2000
# 256   1151000           58.0              1629000  2000
# 257    234000          122.0               461000  2000
# 258   4385000           68.0              5141000  2000
# 259    798000           59.0              2140000  2000

# %%
sns.barplot(x=data['state'],y = data['production'])
plt.xticks(rotation = 90)
plt.show()

# %%
year_2000= df[df['year']== 2000]

year_2000_sorted = year_2000.sort_values(by='colonies_number',ascending = False)

plt.figure(figsize = (10,5))
ax = sns.barplot(x = year_2000_sorted['state'],y= year_2000_sorted['colonies_number'],palette = 'magma',edgecolor='black')

plt.tight_layout()
plt.title('State wise production in year 2000')
plt.xlabel('States')
plt.ylabel('colonies_number')
plt.xticks(rotation=90)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_6371/1372738049.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = year_2000_sorted['state'],y= year_2000_sorted['colonies_number'],palette = 'magma',edgecolor='black')
